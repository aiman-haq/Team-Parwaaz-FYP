# %%
 # !pip3 install face_recognition
 # !pip install Dlib
 # !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting face_recognition
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Program Files\Python310\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\UZIMA\\AppData\\Local\\Temp\\pip-install-sdaa93hk\\dlib_6309403976354ca9bb14daefd6869f55\\setup.py'"'"'; __file__='"'"'C:\\Users\\UZIMA\\AppData\\Local\\Temp\\pip-install-sdaa93hk\\dlib_6309403976354ca9bb14daefd6869f55\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\UZIMA\AppData\Local\Temp\pip-record-f8j8f0iy\install-record.txt' --single-version-externally-managed --user --prefix= --compile --install-headers 'C:\Users\UZIMA\AppData\Roaming\Python\Python310\Include\dlib'
#          cwd: C:\Users\UZIMA\AppData\Local\Temp\pip-install-sdaa93hk\dlib_6309403976354ca9bb14daefd6869f55\
#     Complete output (8 lines):
#     running install
#     running build
#     running build_py
#     package init file 'tools\python\dlib\__init__.py' not found (or not a regular file)
#     running build_ext
#
#     ERROR: CMake must be installed to build dlib
#
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Program Files\Python310\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\UZIMA\\AppData\\Local\\Temp\\pip-install-sdaa93hk\\dlib_6309403976354ca9bb14daefd6869f55\\setup.py'"'"'; __file__='"'"'C:\\Users\\UZIMA\\AppData\\Local\\Temp\\pip-install-sdaa93hk\\dlib_6309403976354ca9bb14daefd6869f55\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\UZIMA\AppData\Local\Temp\pip-record-f8j8f0iy\install-record.txt' --single-version-externally-managed --user --prefix= --compile --install-headers 'C:\Users\UZIMA\AppData\Roaming\Python\Python310\Include\dlib' Check the logs for full command output.
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Program Files\Python310\python.exe -m pip install --upgrade pip' command.
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy in c:\users\uzima\appdata\roaming\python\python310\site-packages (from face_recognition) (1.22.2)
# Collecting dlib>=19.7
#   Using cached dlib-19.23.0.tar.gz (3.2 MB)
# Requirement already satisfied: Pillow in c:\users\uzima\appdata\roaming\python\python310\site-packages (from face_recognition) (9.0.1)
# Requirement already satisfied: face-recognition-models>=0.3.0 in c:\users\uzima\appdata\roaming\python\python310\site-packages (from face_recognition) (0.3.0)
# Collecting Click>=6.0
#   Using cached click-8.0.4-py3-none-any.whl (97 kB)
# Requirement already satisfied: colorama in c:\users\uzima\appdata\roaming\python\python310\site-packages (from Click>=6.0->face_recognition) (0.4.4)
# Using legacy 'setup.py install' for dlib, since package 'wheel' is not installed.
# Installing collected packages: dlib, Click, face-recognition
#     Running setup.py install for dlib: started
#     Running setup.py install for dlib: finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Program Files\Python310\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\UZIMA\\AppData\\Local\\Temp\\pip-install-rt71c33i\\dlib_803aef6b9b0440c59f7cecb7dad81d3c\\setup.py'"'"'; __file__='"'"'C:\\Users\\UZIMA\\AppData\\Local\\Temp\\pip-install-rt71c33i\\dlib_803aef6b9b0440c59f7cecb7dad81d3c\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\UZIMA\AppData\Local\Temp\pip-record-0y61eu0m\install-record.txt' --single-version-externally-managed --user --prefix= --compile --install-headers 'C:\Users\UZIMA\AppData\Roaming\Python\Python310\Include\Dlib'
#          cwd: C:\Users\UZIMA\AppData\Local\Temp\pip-install-rt71c33i\dlib_803aef6b9b0440c59f7cecb7dad81d3c\
#     Complete output (8 lines):
#     running install
#     running build
#     running build_py
#     package init file 'tools\python\dlib\__init__.py' not found (or not a regular file)
#     running build_ext
#
#     ERROR: CMake must be installed to build dlib
#
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Program Files\Python310\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\UZIMA\\AppData\\Local\\Temp\\pip-install-rt71c33i\\dlib_803aef6b9b0440c59f7cecb7dad81d3c\\setup.py'"'"'; __file__='"'"'C:\\Users\\UZIMA\\AppData\\Local\\Temp\\pip-install-rt71c33i\\dlib_803aef6b9b0440c59f7cecb7dad81d3c\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\UZIMA\AppData\Local\Temp\pip-record-0y61eu0m\install-record.txt' --single-version-externally-managed --user --prefix= --compile --install-headers 'C:\Users\UZIMA\AppData\Roaming\Python\Python310\Include\Dlib' Check the logs for full command output.
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Program Files\Python310\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting Dlib
#   Using cached dlib-19.23.0.tar.gz (3.2 MB)
# Using legacy 'setup.py install' for Dlib, since package 'wheel' is not installed.
# Installing collected packages: Dlib
#     Running setup.py install for Dlib: started
#     Running setup.py install for Dlib: finished with status 'error'
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\uzima\appdata\roaming\python\python310\site-packages (4.5.5.62)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\uzima\appdata\roaming\python\python310\site-packages (from opencv-python) (1.22.2)
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Program Files\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import dlib
import cv2
import sys
import os
import face_recognition
import cv2_imshow
from simple_facerec import SimpleFacerec
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\UZIMA\OneDrive\Desktop\FYP5\face-recognition\face-recognition copy.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/UZIMA/OneDrive/Desktop/FYP5/face-recognition/face-recognition%20copy.ipynb#ch0000002?line=0'>1</a> import dlib
#       <a href='vscode-notebook-cell:/c%3A/Users/UZIMA/OneDrive/Desktop/FYP5/face-recognition/face-recognition%20copy.ipynb#ch0000002?line=1'>2</a> import cv2
#       <a href='vscode-notebook-cell:/c%3A/Users/UZIMA/OneDrive/Desktop/FYP5/face-recognition/face-recognition%20copy.ipynb#ch0000002?line=2'>3</a> import sys
#
# ModuleNotFoundError: No module named 'dlib'

# %%
img = cv2.imread("dataset\niha-pic.PNG")
cv2_imshow(img)
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_encoding = face_recognition.face_encodings(rgb_img)[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\UZIMA\OneDrive\Desktop\FYP5\face-recognition\face-recognition copy.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/UZIMA/OneDrive/Desktop/FYP5/face-recognition/face-recognition%20copy.ipynb#ch0000003?line=0'>1</a> img = cv2.imread("dataset\niha-pic.PNG")
#       <a href='vscode-notebook-cell:/c%3A/Users/UZIMA/OneDrive/Desktop/FYP5/face-recognition/face-recognition%20copy.ipynb#ch0000003?line=1'>2</a> cv2_imshow(img)
#       <a href='vscode-notebook-cell:/c%3A/Users/UZIMA/OneDrive/Desktop/FYP5/face-recognition/face-recognition%20copy.ipynb#ch0000003?line=2'>3</a> rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#
# NameError: name 'cv2' is not defined

# %%
img2 = cv2.imread("dataset\niha2.jpg")
cv2_imshow(img2)
rgb_img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img_encoding2 = face_recognition.face_encodings(rgb_img2)[0]
# Out:
# <PIL.Image.Image image mode=RGB size=175x175 at 0x7FC3BAF0DA50>

# %%
result = face_recognition.compare_faces([img_encoding], img_encoding2)
print("Result: ", result)
# Out:
# Result:  [True]

# %% [markdown]
# ## **Video capturing code**

# %%
# Encode faces from a folder
sfr = SimpleFacerec()
sfr.load_encoding_images("/content/drive/MyDrive/Colab Notebooks/parwaaz-face/face-recognition/dataset")

# Load Camera
cap = cv2.VideoCapture("0")


while True:
    ret, frame = cap.read()

    # Detect Faces
    face_locations, face_names = sfr.detect_known_faces(frame)
    for face_loc, name in zip(face_locations, face_names):
        y1, x2, y2, x1 = face_loc[0], face_loc[1], face_loc[2], face_loc[3]

        cv2.putText(frame, name,(x1, y1 - 10), cv2.FONT_HERSHEY_DUPLEX, 1, (0, 0, 200), 2)
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 200), 4)

    cv2_imshow(frame)

    key = cv2.waitKey(1)
    if key == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
